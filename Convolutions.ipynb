# %% [markdown]
# # Deep Learning
# ## Assignment 4
# Previously in 2_fullyconnected.ipynb and 3_regularization.ipynb, we trained fully connected networks to classify notMNIST characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
#
# convolutions need the image data formatted as a cube (width by height by #channels)
#
# labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.048410
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.751892
# Minibatch accuracy: 43.8%
# Validation accuracy: 50.4%
# Minibatch loss at step 100: 0.937118
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.3%
# Minibatch loss at step 150: 0.512477
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 200: 1.303299
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 250: 1.219826
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 300: 0.415192
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 350: 0.414213
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 400: 0.246371
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 1.030782
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 500: 0.722383
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 1.151621
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 600: 0.315360
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 650: 1.115929
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 700: 0.808962
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 750: 0.043841
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 800: 0.797043
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 850: 0.923577
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 900: 0.764273
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 950: 0.638854
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.434733
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Test accuracy: 89.3%

# %% [markdown]
# # Problem 1
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (nn.max_pool()) of stride 2 and kernel size 2.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    max_pool = tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(max_pool, layer2_weights, [1, 1,1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    max_pool = tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1], padding='SAME')
    shape = max_pool.get_shape().as_list()
    reshape = tf.reshape(max_pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.921545
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.874223
# Minibatch accuracy: 12.5%
# Validation accuracy: 39.7%
# Minibatch loss at step 100: 1.098642
# Minibatch accuracy: 62.5%
# Validation accuracy: 64.8%
# Minibatch loss at step 150: 0.388681
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 200: 1.048903
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 250: 1.160157
# Minibatch accuracy: 56.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 300: 0.399977
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 350: 0.432665
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 400: 0.250897
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 450: 0.852614
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 500: 0.703985
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 550: 1.076893
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 600: 0.335712
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 650: 0.886083
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 0.817434
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 750: 0.049043
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 800: 0.541616
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 850: 1.194878
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 900: 0.671257
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 950: 0.507142
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 1000: 0.346328
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# Test accuracy: 90.4%

# %% [markdown]
# # Problem 2

# %% [markdown]
# Try to get the best performance you can using a convolutional net. Look for example at the classic LeNet5 architecture, adding Dropout, and/or adding learning rate decay.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
drop_rate = 0.5

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
#adding layer 5    
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer1_biases)
    max_pool = tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1], padding='VALID')
    conv = tf.nn.conv2d(max_pool, layer2_weights, [1, 1,1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer2_biases)
    max_pool = tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1], padding='VALID')
    shape = max_pool.get_shape().as_list()  
    reshape = tf.reshape(max_pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
#add dropout   
    
    drop = tf.nn.dropout(hidden,drop_rate)
    hidden = tf.nn.relu(tf.matmul(drop, layer4_weights) + layer4_biases)
    drop = tf.nn.dropout(hidden, drop_rate)
    return tf.matmul(drop, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.191211
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 2.139161
# Minibatch accuracy: 18.8%
# Validation accuracy: 14.1%
# Minibatch loss at step 100: 2.010892
# Minibatch accuracy: 12.5%
# Validation accuracy: 21.6%
# Minibatch loss at step 150: 1.815090
# Minibatch accuracy: 25.0%
# Validation accuracy: 29.8%
# Minibatch loss at step 200: 1.776497
# Minibatch accuracy: 31.2%
# Validation accuracy: 37.3%
# Minibatch loss at step 250: 2.201658
# Minibatch accuracy: 18.8%
# Validation accuracy: 40.1%
# Minibatch loss at step 300: 1.369011
# Minibatch accuracy: 50.0%
# Validation accuracy: 44.0%
# Minibatch loss at step 350: 1.049469
# Minibatch accuracy: 56.2%
# Validation accuracy: 45.9%
# Minibatch loss at step 400: 0.942460
# Minibatch accuracy: 68.8%
# Validation accuracy: 47.8%
# Minibatch loss at step 450: 1.462650
# Minibatch accuracy: 62.5%
# Validation accuracy: 45.2%
# Minibatch loss at step 500: 1.877415
# Minibatch accuracy: 56.2%
# Validation accuracy: 52.7%
# Minibatch loss at step 550: 1.085533
# Minibatch accuracy: 68.8%
# Validation accuracy: 58.1%
# Minibatch loss at step 600: 0.952017
# Minibatch accuracy: 68.8%
# Validation accuracy: 57.3%
# Minibatch loss at step 650: 1.632224
# Minibatch accuracy: 56.2%
# Validation accuracy: 61.6%
# Minibatch loss at step 700: 1.113799
# Minibatch accuracy: 68.8%
# Validation accuracy: 59.7%
# Minibatch loss at step 750: 0.630537
# Minibatch accuracy: 68.8%
# Validation accuracy: 62.9%
# Minibatch loss at step 800: 0.996330
# Minibatch accuracy: 75.0%
# Validation accuracy: 60.8%
# Minibatch loss at step 850: 1.092326
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.8%
# Minibatch loss at step 900: 1.225841
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.2%
# Minibatch loss at step 950: 0.757156
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.8%
# Minibatch loss at step 1000: 0.926368
# Minibatch accuracy: 68.8%
# Validation accuracy: 65.9%
# Minibatch loss at step 1050: 0.982213
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.5%
# Minibatch loss at step 1100: 0.857251
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.9%
# Minibatch loss at step 1150: 1.518706
# Minibatch accuracy: 62.5%
# Validation accuracy: 69.1%
# Minibatch loss at step 1200: 1.339183
# Minibatch accuracy: 50.0%
# Validation accuracy: 67.2%
# Minibatch loss at step 1250: 1.021603
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.5%
# Minibatch loss at step 1300: 0.610448
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.2%
# Minibatch loss at step 1350: 1.183519
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.7%
# Minibatch loss at step 1400: 0.638390
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.8%
# Minibatch loss at step 1450: 0.701984
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.5%
# Minibatch loss at step 1500: 1.463733
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.2%
# Minibatch loss at step 1550: 1.209180
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.2%
# Minibatch loss at step 1600: 1.230378
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.3%
# Minibatch loss at step 1650: 1.048681
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.6%
# Minibatch loss at step 1700: 0.671144
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.1%
# Minibatch loss at step 1750: 0.858287
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.6%
# Minibatch loss at step 1800: 0.963033
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 1850: 1.094230
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.8%
# Minibatch loss at step 1900: 0.410560
# Minibatch accuracy: 93.8%
# Validation accuracy: 71.9%
# Minibatch loss at step 1950: 0.986023
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.1%
# Minibatch loss at step 2000: 0.672793
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.4%
# Minibatch loss at step 2050: 1.065629
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.0%
# Minibatch loss at step 2100: 0.421904
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.6%
# Minibatch loss at step 2150: 0.817842
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 2200: 0.796000
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.8%
# Minibatch loss at step 2250: 0.796138
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 2300: 1.489370
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.0%
# Minibatch loss at step 2350: 0.863035
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 2400: 0.514219
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.5%
# Minibatch loss at step 2450: 0.911319
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.8%
# Minibatch loss at step 2500: 1.068216
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 2550: 0.883622
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 2600: 0.465355
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 2650: 0.433733
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss at step 2700: 0.564573
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 2750: 1.816795
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.8%
# Minibatch loss at step 2800: 0.794690
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 2850: 0.294841
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 2900: 0.680982
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 2950: 0.956896
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.8%
# Minibatch loss at step 3000: 1.264791
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.1%
# Minibatch loss at step 3050: 0.868115
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 3100: 0.788607
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.1%
# Minibatch loss at step 3150: 1.460154
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 3200: 0.734015
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 3250: 0.743165
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 3300: 0.367251
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 3350: 0.795613
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.1%
# Minibatch loss at step 3400: 1.250107
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 3450: 0.642171
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step