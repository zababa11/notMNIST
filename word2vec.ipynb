# %% [markdown]
# # Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.067602
# Nearest to so: negativity, outage, ambedkar, bury, classless, welcoming, obsessive, westernmost,
# Nearest to may: biarritz, kittiwake, cga, autodesk, homomorphisms, snl, swim, spines,
# Nearest to time: chivalry, karami, origine, instructed, slogans, doors, immigrant, exploration,
# Nearest to between: freedoms, meditations, acquiescence, coffins, before, meter, livius, ringers,
# Nearest to most: charter, fsf, unsurprisingly, bother, tg, educators, marston, maximus,
# Nearest to has: amundsen, qe, bugle, embellished, orthodox, udo, bran, incompatibility,
# Nearest to its: leftmost, basset, spamming, privilege, dil, category, sabra, acuity,
# Nearest to these: penitence, medical, inerrancy, sally, knute, oshii, submarine, newsreel,
# Nearest to war: hiroshi, wetter, gwynedd, calypso, boy, centurion, savoury, denison,
# Nearest to when: conformed, reservoir, composting, abandons, briggs, jellicoe, stargate, peake,
# Nearest to not: jaffa, histone, kullervo, ld, watford, koch, sturgis, whalers,
# Nearest to would: celibate, erdrich, shilling, espoo, optic, anthroposophy, ordeal, birthplace,
# Nearest to will: torment, sleeps, harsher, ogdoad, insufficient, infinitely, agitating, jab,
# Nearest to have: cantigas, thermonuclear, norodom, laramie, bibliography, exe, uploading, stairs,
# Nearest to as: eben, la, inch, oeuvres, nicol, dinaric, skookum, simulation,
# Nearest to b: migne, ghostly, newcastle, milken, hygienic, sive, abhidhamma, assaults,
# Average loss at step 2000: 4.368899
# Average loss at step 4000: 3.865340
# Average loss at step 6000: 3.790898
# Average loss at step 8000: 3.684156
# Average loss at step 10000: 3.615225
# Nearest to so: negativity, suda, atchison, dios, jiva, hormone, we, egoist,
# Nearest to may: can, would, could, robotics, decomposing, kittiwake, dwarves, amorites,
# Nearest to time: wegener, punishes, chivalry, bitumen, precepts, concluded, outgassing, franklin,
# Nearest to between: freedoms, before, equine, with, in, velocity, difficulty, mediating,
# Nearest to most: use, muslims, northside, puritanism, particular, marston, clinicians, cramer,
# Nearest to has: had, was, is, have, eclac, bugle, orthodox, subscriber,
# Nearest to its: their, the, his, sabra, leftmost, candela, category, this,
# Nearest to these: medical, penitence, sally, abundantly, weighs, democritus, galton, therapeutic,
# Nearest to war: ingeborg, supranational, gwynedd, breweries, transparent, ligature, centurion, perpetrators,
# Nearest to when: although, dualist, keaton, greek, peake, final, where, oldenburg,
# Nearest to not: also, they, often, who, interactivity, there, generally, avatars,
# Nearest to would: could, can, may, oxidizing, will, ime, logarithmic, celibate,
# Nearest to will: can, could, critics, would, newly, pope, sleeps, vila,
# Nearest to have: had, be, has, cantigas, timber, moreno, are, sierpinski,
# Nearest to as: by, charlize, eben, pious, restarted, yard, salty, ozone,
# Nearest to b: d, punish, migne, flared, monologues, piacenza, globin, offal,
# Average loss at step 12000: 3.605915
# Average loss at step 14000: 3.577341
# Average loss at step 16000: 3.413698
# Average loss at step 18000: 3.462057
# Average loss at step 20000: 3.539614
# Nearest to so: atchison, volhynia, tetrapods, negativity, spyware, upto, codec, interlude,
# Nearest to may: can, would, could, will, should, must, robotics, dwarves,
# Nearest to time: concluded, wegener, precepts, chivalry, bitumen, confer, sasson, punishes,
# Nearest to between: freedoms, with, before, chico, equine, in, exposes, egalitarianism,
# Nearest to most: use, muslims, wavefunctions, micah, puritanism, many, particular, some,
# Nearest to has: had, is, was, have, boleslaus, bugle, apprehend, eclac,
# Nearest to its: their, his, her, the, leftmost, candela, sabra, this,
# Nearest to these: many, some, medical, which, other, all, abundantly, giver,
# Nearest to war: ingeborg, breweries, supranational, gwynedd, carvalho, deceiver, adoptionism, ligature,
# Nearest to when: although, where, clifford, if, bilirubin, solitary, was, during,
# Nearest to not: also, they, generally, usually, it, too, still, often,
# Nearest to would: could, can, will, may, must, might, oxidizing, did,
# Nearest to will: would, can, could, may, must, critics, to, rehearsals,
# Nearest to have: had, has, are, be, were, take, make, diethyl,
# Nearest to as: salty, jet, constitutional, basutoland, oeuvres, ers, shogun, crane,
# Nearest to b: d, flared, alex, punish, slugs, germ, dafoe, airliner,
# Average loss at step 22000: 3.502287
# Average loss at step 24000: 3.489742
# Average loss at step 26000: 3.484299
# Average loss at step 28000: 3.478628
# Average loss at step 30000: 3.507285
# Nearest to so: healer, lolita, volhynia, atchison, formally, foss, tentatively, upto,
# Nearest to may: can, would, could, will, must, should, might, dwarves,
# Nearest to time: concluded, netbios, blondie, place, wegener, init, upto, bitumen,
# Nearest to between: with, before, chico, freedoms, in, abolitionist, exposes, egalitarianism,
# Nearest to most: use, more, wavefunctions, muslims, cramer, ibu, lok, micah,
# Nearest to has: had, have, is, was, kingship, boleslaus, apprehend, anni,
# Nearest to its: their, his, her, the, candela, barthes, sabra, fuses,
# Nearest to these: some, many, all, they, such, which, medical, their,
# Nearest to war: breweries, ingeborg, supranational, adoptionism, stolen, gwynedd, boy, savoury,
# Nearest to when: if, where, after, during, although, but, clifford, until,
# Nearest to not: they, it, little, generally, still, necessarily, usually, interactivity,
# Nearest to would: could, can, will, may, must, should, might, did,
# Nearest to will: can, would, could, may, must, should, cannot, critics,
# Nearest to have: had, has, are, were, be, refer, having, suffice,
# Nearest to as: salty, transforming, moveable, monica, inductor, becomes, by, with,
# Nearest to b: d, alex, flared, slugs, hypothermia, busan, freemason, germ,
# Average loss at step 32000: 3.500587
# Average loss at step 34000: 3.496902
# Average loss at step 36000: 3.453493
# Average loss at step 38000: 3.301903
# Average loss at step 40000: 3.425838
# Nearest to so: healer, formally, lolita, seminary, upto, foss, bulls, dhole,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to time: concluded, place, netbios, way, init, punishes, companions, relocating,
# Nearest to between: before, with, ruthlessness, chico, bros, ping, carols, psk,
# Nearest to most: more, use, many, recognition, muslims, wavefunctions, tenants, cramer,
# Nearest to has: had, have, was, is, boleslaus, kingship, reaches, amazement,
# Nearest to its: their, his, her, the, barthes, stiff, foliage, leftmost,
# Nearest to these: many, some, they, such, several, all, various, medical,
# Nearest to war: ingeborg, adoptionism, supranational, breweries, savoury, stolen, bowel, steinbeck,
# Nearest to when: if, where, while, after, during, although, but, was,
# Nearest to not: they, little, never, necessarily, generally, still, usually, also,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to will: can, would, could, may, must, should, cannot, might,
# Nearest to have: had, has, were, are, be, refer, having, previously,
# Nearest to as: when, ers, becomes, by, inductor, ithilien, vba, shingles,
# Nearest to b: d, UNK, c, alex, sive, l, flared, backstory,
# Average loss at step 42000: 3.436455
# Average loss at step 44000: 3.450794
# Average loss at step 46000: 3.449298
# Average loss at step 48000: 3.352970
# Average loss at step 50000: 3.382760
# Nearest to so: healer, foss, lolita, seminary, grape, interlude, repudiated, jaguars,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to time: way, year, place, companions, netbios, day, init, punishes,
# Nearest to between: with, against, chico, in, ping, before, among, freedoms,
# Nearest to most: more, use, loans, some, recognition, wavefunctions, polarizing, among,
# Nearest to has: had, have, was, is, kingship, cautionary, having, kkinen,
# Nearest to its: their, his, the, her, stiff, barthes, some, metastasis,
# Nearest to these: some, many, both, several, various, such, those, they,
# Nearest to war: adoptionism, breweries, ingeborg, supranational, block, savoury, daytime, certificates,
# Nearest to when: while, after, if, where, although, however, before, during,
# Nearest to not: never, usually, they, generally, still, interactivity, necessarily, it,
# Nearest to would: will, could, can, may, must, should, might, did,
# Nearest to will: would, could, can, must, may, cannot, should, might,
# Nearest to have: had, has, were, are, be, refer, having, ever,
# Nearest to as: transforming, like, kam, salty, when, becomes, became, after,
# Nearest to b: d, bru, busan, sive, c, backstory, slapstick, alex,
# Average loss at step 52000: 3.436786
# Average loss at step 54000: 3.424951
# Average loss at step 56000: 3.438926
# Average loss at step 58000: 3.393290
# Average loss at step 60000: 3.388919
# Nearest to so: lolita, foss, seminary, healer, grape, dhole, jaguars, repudiated,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to time: way, place, period, companions, year, success, wimp, retrospectively,
# Nearest to between: with, among, within, chico, ping, through, in, ruthlessness,
# Nearest to most: more, use, some, loans, wavefunctions, waist, many, recognition,
# Nearest to has: had, have, was, is, kingship, having, spectacled, seems,
# Nearest to its: their, his, the, her, our, dong, debugging, summers,
# Nearest to these: some, many, several, those, which, both, such, they,
# Nearest to war: adoptionism, battle, daytime, wars, breweries, supranational, wiccans, stolen,
# Nearest to when: if, while, after, although, before, during, where, because,
# Nearest to not: usually, never, still, sufficient, they, now, lemy, almost,
# Nearest to would: will, could, may, can, should, must, might, did,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to have: has, had, are, refer, were, having, include, be,
# Nearest to as: salty, inductor, deposits, regius, like, jed, gather, transforming,
# Nearest to b: d, c, m, bru, r, p, busan, h,
# Average loss at step 62000: 3.249288
# Average loss at step 64000: 3.254526
# Average loss at step 66000: 3.408030
# Average loss at step 68000: 3.394270
# Average loss at step 70000: 3.360415
# Nearest to so: lolita, repudiated, seminary, foss, grape, bulls, sacagawea, dhole,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to time: way, place, period, companions, netbios, wimp, concluded, kind,
# Nearest to between: with, within, among, in, chico, estas, from, tinctures,
# Nearest to most: more, some, many, use, less, wisely, increasingly, particularly,
# Nearest to has: had, have, is, was, kingship, contains, since, gerd,
# Nearest to its: their, his, her, the, our, dong, clocks, nitro,
# Nearest to these: some, many, such, are, those, several, which, the,
# Nearest to war: wars, adoptionism, battle, cia, daytime, steinbeck, wiccans, breweries,
# Nearest to when: if, while, after, before, however, where, because, although,
# Nearest to not: never, generally, usually, still, necessarily, sufficient, almost, now,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to have: had, has, were, are, be, refer, having, include,
# Nearest to as: kam, salty, transforming, urinate, is, like, elkins, when,
# Nearest to b: d, bru, h, f, m, r, p, sive,
# Average loss at step 72000: 3.375558
# Average loss at step 74000: 3.344741
# Average loss at step 76000: 3.316147
# Average loss at step 78000: 3.354031
# Average loss at step 80000: 3.380606
# Nearest to so: lolita, repudiated, sacagawea, bulls, foss, anything, when, spyware,
# Nearest to may: can, will, could, should, would, must, might, cannot,
# Nearest to time: companions, wimp, place, period, way, concluded, year, punishes,
# Nearest to between: among, within, with, chico, through, estas, egalitarianism, over,
# Nearest to most: many, some, more, loans, particularly, wavefunctions, dissatisfied, muslims,
# Nearest to has: had, have, is, was, kingship, percival, although, since,
# Nearest to its: their, his, her, our, the, bogdanovich, dong, qualified,
# Nearest to these: several, those, many, both, some, such, various, are,
# Nearest to war: wars, adoptionism, battle, daytime, breweries, wiccans, constable, block,
# Nearest to when: before, after, if, during, while, although, though, where,
# Nearest to not: still, never, usually, it, often, sufficient, generally, we,
# Nearest to would: will, could, may, should, can, might, must, cannot,
# Nearest to will: would, may, can, could, must, should, might, cannot,
# Nearest to have: had, has, are, having, were, refer, be, include,
# Nearest to as: before, kam, urinate, salty, pew, transforming, after, honecker,
# Nearest to b: d, c, bru, m, f, p, teamwork, sheep,
# Average loss at step 82000: 3.408833
# Average loss at step 84000: 3.414879
# Average loss at step 86000: 3.384603
# Average loss at step 88000: 3.352016
# Average loss at step 90000: 3.363876
# Nearest to so: lolita, anything, bulls, repudiated, thus, sacagawea, what, finally,
# Nearest to may: can, could, will, should, must, would, might, cannot,
# Nearest to time: way, wimp, period, year, day, companions, concluded, place,
# Nearest to between: with, within, among, through, chico, in, tinctures, from,
# Nearest to most: more, some, many, less, particularly, bloomberg, especially, use,
# Nearest to has: had, have, is, was, since, although, includes, requires,
# Nearest to its: their, his, the, her, our, cmos, dong, bogdanovich,
# Nearest to these: several, many, some, such, various, those, both, are,
# Nearest to war: battle, wars, adoptionism, premises, daytime, cia, constable, breweries,
# Nearest to when: before, if, while, after, during, where, although, since,
# Nearest to not: still, generally, they, sufficient, never, now, it, otherwise,
# Nearest to would: will, could, can, should, may, might, must, cannot,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to have: had, has, having, were, refer, be, are, exhibit,
# Nearest to as: urinate, inductor, pew, kam, before, alleles, varna, multimedia,
# Nearest to b: d, c, y, k, bru, m, f, h,
# Average loss at step 92000: 3.398450
# Average loss at step 94000: 3.253009
# Average loss at step 96000: 3.356084
# Average loss at step 98000: 3.245274
# Average loss at step 100000: 3.356394
# Nearest to so: thus, lolita, bulls, anything, tentatively, englewood, too, then,
# Nearest to may: can, could, should, must, would, will, might, cannot,
# Nearest to time: way, companions, period, wimp, gatherer, concluded, year, retrospectively,
# Nearest to between: with, through, among, within, chico, into, tinctures, estas,
# Nearest to most: more, less, particularly, many, especially, some, increasingly, sheer,
# Nearest to has: had, have, is, was, kingship, since, having, spectacled,
# Nearest to its: their, his, her, the, our, bogdanovich, cmos, divorcing,
# Nearest to these: several, many, some, various, those, all, both, different,
# Nearest to war: battle, wars, adoptionism, daytime, constable, struggle, cia, premises,
# Nearest to when: before, if, while, after, during, although, where, without,
# Nearest to not: still, never, actually, generally, otherwise, they, t, almost,
# Nearest to would: will, could, can, should, may, might, must, cannot,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to have: had, has, refer, were, are, having, be, tend,
# Nearest to as: salty, becomes, kam, like, urinate, factorizations, disenfranchised, magnet,
# Nearest to b: d, c, slugs, alex, airliner, bru, stu, colonised,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
#TODO
